# %% [markdown]
# Kuldeep Singh Chouhan
# <br>
# 200530

# %%
from qiskit import QuantumCircuit, Aer, assemble, execute, BasicAer
from qiskit_textbook.tools import array_to_latex
from qiskit.tools.visualization import plot_histogram
import numpy as np

# %% [markdown]
# ### Task 0:

# %% [markdown]
# #### i) Create swap circuit without using inbuilt swap function.                                                 (5)

# %%
circ=QuantumCircuit(2,2)

circ.cx(0,1)
circ.cx(1,0)
circ.cx(0,1)

# %% [markdown]
# #### ii) Visualize your circuit and verify using state-vector simulator. (3)

# %%
circ.draw(initial_state=True, cregbundle=False, output='mpl')

# %% [markdown]
# swapping $(|0 \rangle,| 1 \rangle)$ to get $(|1 \rangle,| 0 \rangle)$ <br>
# initializing the second qubit with $| 1 \rangle$

# %%
circ=QuantumCircuit(2,2)
circ.initialize([0,1],1) # this for 
circ.cx(0,1)
circ.cx(1,0)
circ.cx(0,1)
circ.measure([1],[1])
simulator = Aer.get_backend('statevector_simulator')                          # obtain a state_vector_simulator
qobj = assemble(circ)                                                                                         # assemble the circuit
final_state = simulator.run(qobj).result().get_statevector()                # run simulator to get get final state
array_to_latex(final_state, pretext="\\text{Statevector} = ")    
circ.draw(initial_state=True, cregbundle=False, output='mpl')
# Out:
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# 0 \\
# 1 \\
# 0 \\
# 0
# \end{bmatrix}
# $

# %% [markdown]
# #### iii) Measure the qubits using classical registers. (2)

# %%
simulator = Aer.get_backend('qasm_simulator')
job =  execute(circ, backend = simulator, shots=100) 
result = job.result()
counts = result.get_counts(circ)
print(counts)
plot_histogram(counts)
# Out:
# {'00': 100}

# %% [markdown]
# ### Task 1: Create Equal Superposition on 2 qubits. (10)

# %%
circ1 = QuantumCircuit(2)
circ1.h(0)
circ1.h(1)
simulator = Aer.get_backend('statevector_simulator')                          # obtain a state_vector_simulator
qobj = assemble(circ1)                                                                                         # assemble the circuit
final_state = simulator.run(qobj).result().get_statevector()                # run simulator to get get final state
array_to_latex(final_state, pretext="\\text{Statevector} = ")              #d isplay the state vector
circ1.draw(initial_state=True, cregbundle=False, output='mpl')
# Out:
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# \tfrac{1}{2} \\
# \tfrac{1}{2} \\
# \tfrac{1}{2} \\
# \tfrac{1}{2}
# \end{bmatrix}
# $

# %% [markdown]
# ### Task 2:

# %% [markdown]
# #### i) Create Entangled State $\frac{|00\rangle + |11\rangle}{\sqrt 2}$.   (5)

# %%
circ2 = QuantumCircuit(2)
# circ2.initialize([0,1],0) # this for
circ2.h(1) 
circ2.cx(1,0)

# circ2.initialize([0,1],0) # this for

simulator = Aer.get_backend('statevector_simulator')                          # obtain a state_vector_simulator
qobj = assemble(circ2)                                                                                         # assemble the circuit
final_state = simulator.run(qobj).result().get_statevector()                # run simulator to get get final state
array_to_latex(final_state, pretext="\\text{Statevector} = ")              #d isplay the state vector
circ2.draw(initial_state=True, cregbundle=False, output='mpl')
# Out:
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} \\
# 0 \\
# 0 \\
# \tfrac{1}{\sqrt{2}}
# \end{bmatrix}
# $

# %% [markdown]
# #### ii) Measure 1st qubit, 2nd qubit, and then both qubit. (5)

# %%
circ3 = QuantumCircuit(2,2)
# circ2.initialize([0,1],0) # this for
circ3.h(1) 
circ3.cx(1,0)
circ3.measure([0],[0])
circ3.draw(initial_state=True, cregbundle=False, output='mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')                          # obtain a state_vector_simulator
qobj1 = assemble(circ3)                                                                                         # assemble the circuit
final_state1 = simulator.run(qobj1).result().get_statevector()                # run simulator to get get final state
array_to_latex(final_state1, pretext="\\text{Statevector} = ")
# Out:
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# 1 \\
# 0 \\
# 0 \\
# 0
# \end{bmatrix}
# $

# %%
circ3 = QuantumCircuit(2,2)
# circ2.initialize([0,1],0) # this for
circ3.h(1) 
circ3.cx(1,0)
circ3.measure([1],[1])
simulator1 = Aer.get_backend('statevector_simulator')                          # obtain a state_vector_simulator
qobj2 = assemble(circ3)                                                                                         # assemble the circuit
final_state2 = simulator1.run(qobj2).result().get_statevector()                # run simulator to get get final state
array_to_latex(final_state2, pretext="\\text{Statevector} = ") 
circ3.draw(initial_state=True, cregbundle=False, output='mpl')
# Out:
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# 1 \\
# 0 \\
# 0 \\
# 0
# \end{bmatrix}
# $

# %%
circ3 = QuantumCircuit(2,2)
# circ2.initialize([0,1],0) # this for
circ3.h(1) 
circ3.cx(1,0)
circ3.measure([0,1],[0,1])

simulator = Aer.get_backend('statevector_simulator')                          # obtain a state_vector_simulator
qobj1 = assemble(circ2)                                                                                         # assemble the circuit
final_state1 = simulator.run(qobj1).result().get_statevector()                # run simulator to get get final state
array_to_latex(final_state1, pretext="\\text{Statevector} = ")              #d isplay the state vector
circ3.draw(initial_state=True, cregbundle=False, output='mpl')
# Out:
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} \\
# 0 \\
# 0 \\
# \tfrac{1}{\sqrt{2}}
# \end{bmatrix}
# $

# %% [markdown]
# #### ii) Verify using state-vector simulator that the circuit works (5)

# %%
simulator = Aer.get_backend('statevector_simulator')                          # obtain a state_vector_simulator
qobj1 = assemble(circ2)                                                                                         # assemble the circuit
final_state1 = simulator.run(qobj1).result().get_statevector()                # run simulator to get get final state
array_to_latex(final_state1, pretext="\\text{Statevector} = ")              #d isplay the state vector
circ3.draw(initial_state=True, cregbundle=False, output='mpl')
simulator = Aer.get_backend('qasm_simulator')
job =  execute(circ3, backend = simulator, shots=100) 
result = job.result()
counts = result.get_counts(circ3)
print(counts)
plot_histogram(counts)
# Out:
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} \\
# 0 \\
# 0 \\
# \tfrac{1}{\sqrt{2}}
# \end{bmatrix}
# $
# {'00': 52, '11': 48}

# %% [markdown]
# ### Task 3:

# %% [markdown]
# #### i) Perform CNOT operation $x, y, z \rightarrow x, y, x \oplus z$, without direct interaction between $x$ and $z$. (10)

# %%
circ4 = QuantumCircuit(3)
circ4.cnot(0,1)
circ4.cnot(1,2)
circ4.cnot(0,1)
circ4.cnot(1,2)
circ4.draw(initial_state=True, cregbundle=False, output='mpl')

# %% [markdown]
# #### ii) Show the action of the circuit as matrix. (5)

# %%
simulator4 = Aer.get_backend('unitary_simulator')                    # obtain a state_vector_simulator
qobj4 = execute(circ4, simulator4, shots=1000)                                                                                         # assemble the circuit
out4 = qobj4.result()             # run simulator to get get final state
print(out4.get_unitary(circ4))           #d isplay the state vector
# Out:
# Operator([[1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#           [0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j],
#           [0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#           [0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j],
#           [0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#           [0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#           [0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j],
#           [0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j]],
#          input_dims=(2, 2, 2), output_dims=(2, 2, 2))
